# %% [markdown]
# # Analysis of Adult income dataset

# %% [markdown]
# - By Ardra P

# %% [markdown]
# ## Dataset Link

# %% [markdown]
# https://www.kaggle.com/datasets/wenruliu/adult-income-dataset

# %% [markdown]
# ## Task 1

# %% [markdown]
# Pick a dataset that interests you (e.g., a CSV file from Kaggle or a public dataset). Start by loading the data into your preferred data analysis tool, such as Python with Pandas or R with dplyr. Explore the dataset by checking the dimensions, summary statistics, and data types. Create visualizations like bar plots, histograms, or scatter plots to gain insights into the data. Identify trends, correlations, and interesting patterns within the dataset

# %% [markdown]
# ## Dataset Describtion

# %% [markdown]
# - An individual’s annual income results from various factors. Intuitively, it is influenced by the individual’s education level, age, gender, occupation, and etc.

# %% [markdown]
# - Age: The age of an individual, represented as a numerical value.
#
# - Workclass: The type of employment, such as Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked, etc.
#
# - Fnlwgt: Final weight. This is the number of people the census believes the entry represents. This is a weighting factor applied to make the sample more representative of the total population.
#
# - Education: The highest level of education achieved by the individual, such as Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
#
# - Education.num: A numerical representation of the educational level.
#
# - Marital.status: Marital status of the individual, such as Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
#
# - Occupation: The type of occupation or job, such as Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
#
# - Relationship: Relationship status of the individual in the family, such as Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
#
# - Race: Race of the individual, such as White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
#
# - Sex: Gender of the individual, either Male or Female.
#
# - Capital.gain: Capital gains for the individual.
#
# - Capital.loss: Capital losses for the individual.
#
# - Hours.per.week: The number of working hours per week.
#
# - Native.country: Country of origin or native country of the individual.
#
# - Income: The target variable, indicating whether the individual's income is above or below a certain threshold.
#     This is often represented as '>50K' or '<=50K', indicating whether the person earns more than $50,000 per year.

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the dataset

# %%
df=pd.read_csv('adult_income.csv')

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race  sex  capital.gain  capital.loss  \
# 0                  ?  Not-in-family  White    1             0          4356
# 1    Exec-managerial  Not-in-family  White    1             0          4356
# 2                  ?      Unmarried  Black    1             0          4356
# 3  Machine-op-inspct      Unmarried  White    1             0          3900
# 4     Prof-specialty      Own-child  White    1             0          3900
#
#    hours.per.week native.country income
# 0              40  United-States  <=50K
# ...

# %% [markdown]
# ## Data Analysis

# %%
df['workclass'].replace({'?':np.nan},inplace=True)

# %% [markdown]
# ## Dimensions

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# ## Statistical informations

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             32561.0      38.581647      13.640433     17.0      28.0
# fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# education.num   32561.0      10.080679       2.572720      1.0       9.0
# sex             32561.0       0.330795       0.470506      0.0       0.0
# capital.gain    32561.0    1077.648844    7385.292085      0.0       0.0
# capital.loss    32561.0      87.303830     402.960219      0.0       0.0
# hours.per.week  32561.0      40.431344      12.358681      0.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178356.0  237051.0  1484705.0
# education.num       10.0      12.0       16.0
# sex                  0.0       1.0        1.0
# capital.gain         0.0       0.0    99999.0
# capital.loss         0.0       0.0     4356.0
# hours.per.week      40.0      45.0       99.0

# %% [markdown]
# ## Data Types

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex                int64
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %% [markdown]
# ## EDA

# %%
sns.histplot(df['age'],kde=True)
plt.title('Age Distribution')
plt.axvline(df['age'].mean(),color='red')
plt.show()

# %% [markdown]
# **age is a positively skewed distribution here .**
#    **more number of peoples are working in the age between 25 to 45**,
#              **there is only less number of peoples are working in the age category greater than 60**,
#                      **the mean age is around 39**,
#                                **the variability of age iis medium**

# %%
df['education'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# - here more number of peoples are completed highschool,
# - there is only a few peoples who had completed preschool and 4th std education
# - comparatevely people who had completed college and bachelors are higher

# %%
s=df['education.num'].value_counts()
plt.pie(s,labels=s.index,autopct='%.2f%%')
plt.show()

# %%
df.plot(kind='box')
plt.tight_layout()
plt.xticks(rotation=90)
# Out:
# (array([1, 2, 3, 4, 5, 6, 7]),
#  [Text(1, 0, 'age'),
#   Text(2, 0, 'fnlwgt'),
#   Text(3, 0, 'education.num'),
#   Text(4, 0, 'sex'),
#   Text(5, 0, 'capital.gain'),
#   Text(6, 0, 'capital.loss'),
#   Text(7, 0, 'hours.per.week')])

# %% [markdown]
# - more outliers are presented in fnlwgt data and capital gain

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90       NaN   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66       NaN  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# - the graph shows that the variables have low correlation with each other

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90       NaN   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66       NaN  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
sns.pairplot(df,diag_kind='kde')

# %% [markdown]
# - fnlwght and age are in -ve correlation
# - variance in capital gain and capital loss is very small
